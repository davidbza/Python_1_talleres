# %% [markdown]
# <a href="https://colab.research.google.com/github/davidbza/Python_1_talleres/blob/main/Taller_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="120px" src="https://www.udea.edu.co/wps/wcm/connect/udea/df55724e-3ebc-46c6-b608-fb9206b3fede/facultad-economicas.png?MOD=AJPERES&CVID=nc5zPyj" align="Center" hspace="10px" vspace="10px"></p>
#
#
# #***Python I - Introducción a modelos económicos y financieros con Python***
#
# ---
#
#
# #**Sesión 6**
# # Docente: *Cristian Ruiz Parra*
#
# ---
# - Control de flujos

# %% [markdown]
# # **Toma de decisiones **
#
# En el desarrollo de esta sesión, seremos capaces de realizar bloques de código para que el programa tome decisiones y repita tareas para resolver problemas complejos

# %% [markdown]
# **Operadores de comparación**
#
# "==" (Igual a, comparar dos valores)  no confundir "=" que es para asignar
#
# "!=" (Diferente de)
#
# ">" (Mayor que)
#
# "<" (Menor que)
#
# ">=" (Mayor o igual que)
#
# "<=" (Menor o igual que)

# %% [markdown]
# #**El Condicional (if)**
#
# Es la estructura basica de decisión que permite ejecutar un código solo se se cumple una condición especifica.
#
# **¡Recuerdo!**: Es importante recordar el concepto de **Indentación**, que es el tab o los 4 espacios(por convención) para saber que el codigo pertenece al (if)

# %%
# Sintaxis básica
if condición:
    # código a ejecutar si la condición es True
# Out:
#   File "/tmp/ipython-input-544892465.py", line 3
#     # código a ejecutar si la condición es True
#                                                ^
# SyntaxError: incomplete input

# %%
##Ejemplo 1: Control de edad
edad = 20

if edad >= 18:
    print("Acceso permitido. Eres mayor de edad.")

print("El programa ha terminado.") # Esta línea está fuera del if
# Out:
# Acceso permitido. Eres mayor de edad.
# El programa ha terminado.

# %%
# Ejemplo 2: Verificar contraseña
contraseña = "secreto123"
if contraseña == "secreto123":
    print("Contraseña correcta")
# Out:
# Contraseña correcta

# %% [markdown]
# **El Booleano (True/False)**
# - Los condicionales se reduce a una pregunta de si o no (True o False)
#
# Ejemplos
#
# print(5 > 3) a la pregunta ¿Es 5 mayor que 3? la respuesta es: Verdadero (True)
#
# print(10 == 20) ¿Es 10 igual a 20? Respuesta: False

# %%
print(5 > 3)
print(10 == 20)
# Out:
# True
# False

# %% [markdown]
# # **Else** De otro modo
#
#  esta instrucción da la acción a realizar en caso que la condición en el if o en elsif (Si anidado) no se cumpliera.
#
#  Va acompañado de dos puntos **else:**

# %%
# Ejemplo 1: Número par o impar
numero = 7

if numero % 2 == 0:              #Si el residuo al dividir por 2 es distinto es cero
    print(f"{numero} es par")    #entonces es un número par
else:                            #De lo contrario
    print(f"{numero} es impar")  #Es un número impar
# Out:
# 7 es impar

# %%
# Ejemplo 2: Aprobado o reprobado
calificación = 85

if calificación >= 70:     #Si la variable "Calificación es mayor o igual que 70"
    print("¡Aprobado!")    #Entonces Aprobado
else:                      #De lo contrario
    print("¡Reprobado!")   #Reprobado
# Out:
# ¡Aprobado!

# %% [markdown]
# #**Elif** Significa "si no... entonces si"
#
# permite comprobar múltiples condiciones una despues de la otra y ejecuta el primero que sea verdadero
#
# Permite elegir una opción entre varias posibilidades excluyentes
#
# *Permite manejar  decisiones que dependen de una decisión anterior*

# %%
nota = 75

if nota >= 90:
    print("A")
elif nota >= 80:
    print("B")
elif nota >= 70:
    print("C") # Python entra aquí, da "C", y TERMINA.
elif nota >= 60:
    print("D") # Esta línea nunca se evalúa
else:
    print("F")
# Out:
# C

# %% [markdown]
# #**Si anidado** (if...if...if)
#
# Se usa para generar un condicional dentro de otro, teniendo estos una jerarquia, y solo evaluara el siguiente nivel si en el primero se encontro un True

# %%
tienes_entrada = True
eres_VIP = False

if tienes_entrada == True:
    print("Bienvenido. Tienes entrada.")

    # IF ANIDADO
    if eres_VIP == True:
        print("Pasa a la zona VIP.")
    else:
        print("Disfruta la zona general.")

else:
    print("No puedes entrar.")
# Out:
# Bienvenido. Tienes entrada.
# Disfruta la zona general.

# %% [markdown]
# # **Operadores lógicos and y or**
#
# Son comparativos de al menos dos condiciones para poder ejecutar un bloque de código
#
# and: Evalua las condiciones y en todas deben arrojar True
#
# or: Evalua que al menos una de las condiciones arroje un true
#
# not: Evalua que se cumpla una sentecia negativa para poder continuar al siguiente paso, es decir busca un false

# %%
# AND (y) - Ambas condiciones deben ser True
edad = 25
tiene_licencia = True

if edad >= 18 and tiene_licencia:
    print("Puedes conducir")
else:
    print("Toco en metro")

# OR (o) - Al menos una condición debe ser True
es_fin_de_semana = False
es_feriado = True

if es_fin_de_semana or es_feriado:
    print("No hay clases")
else:
    print("Hay clases")

# NOT (no) - Invierte el resultado
es_admin = False

if not es_admin:
    print("Acceso limitado")
else:
    print("Acceso total")
# Out:
# Puedes conducir
# No hay clases
# Acceso limitado

# %% [markdown]
# # **El ciclo While (Mientras)**
#
# El objetivo de este ciclo es repetir un bloque de codigo mientras una condición sea True, tiene un riesgo y es que si la condición nunca se vuelve false, el programa se ejecutra hasta que se cuelgue

# %%
#Cuenta Regresiva la prueba se volvera false en el momento que sea un valor negativo

contador = 5

while contador > 0:
    print(contador)
    contador = contador - 1 # ¡La línea de escape! Sin esto, es un ciclo infinito.

print("¡Despegue!")
# Out:
# 5
# 4
# 3
# 2
# 1
# ¡Despegue!

# %% [markdown]
# #** El ciclo for (Para cada)**
#
# Este ciclo itera sobre una secuencia, de elementos almacenados en una variable, y va a hacer  una acción sobre cada una de ellas o sobre el segmento que se delimite de ellas.

# %%
frutas = ["Manzana", "Pera", "Naranja", "Banana"]

for una_fruta in frutas:
    print(f"Me voy a comer una {una_fruta}")
# Out:
# Me voy a comer una Manzana
# Me voy a comer una Pera
# Me voy a comer una Naranja
# Me voy a comer una Banana

# %% [markdown]
# La función **Range** es un buen complemento del ciclo for, pues permite crear listas de elementos que pueden interactuar con las variables del ciclo

# %%
#Tabla del 7
numero = 7
for i in range(1, 11): # Del 1 al 10
    print(f"{numero} x {i} = {numero * i}")
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %% [markdown]
# #**Contoladores de ciclos (break y continue)**
#
# **break** termina el ciclo inmediatamente
#
# **continue** contninua a la siguiente iteración del ciclo, ignorando el resto del código de esa vuelta

# %%
# Buscar un número en una lista
numeros = [5, 8, 3, 12, 7, 9]
buscar = 12

for numero in numeros:
    print(f"Revisando el número: {numero}")
    if numero == buscar:
        print("¡Número encontrado!")
# Out:
# Revisando el número: 5
# Revisando el número: 8
# Revisando el número: 3
# Revisando el número: 12
# ¡Número encontrado!
# Revisando el número: 7
# Revisando el número: 9

# %%
# Buscar un número en una lista y salir cuando lo encuentre
numeros = [5, 8, 3, 12, 7, 9]
buscar = 12

for numero in numeros:
    print(f"Revisando el número: {numero}")
    if numero == buscar:
        print("¡Número encontrado!")
        break  # Sale del ciclo inmediatamente

print("Búsqueda terminada")
# Out:
# Revisando el número: 5
# Revisando el número: 8
# Revisando el número: 3
# Revisando el número: 12
# ¡Número encontrado!
# Búsqueda terminada

# %%
for num in range(1, 11):
    if num % 2 != 0: # Si el número es impar...
          continue   # ...sáltatelo y ve al siguiente número
    print(num) # Esta línea solo se ejecuta para pares
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# # . Proyecto Práctico: "Adivina el Número"
# ¡Vamos a construir un juego!
# Reglas:
#
# 1. La computadora elegirá un número aleatorio (ej. entre 1 y 100).
#
# 2. Usaremos un ciclo while para que el usuario pueda seguir intentando.
#
# 3. Usaremos input() para pedir un número al usuario.
#
# 4. Usaremos if/elif/else para decirle si su número es "muy alto" o "muy bajo".
#
# 5. Usaremos break para salir del ciclo cuando adivine.

# %%
import random
numero_secreto = random.randint(1, 100)
intentos = 0
print("¡Bienvenido al juego de adivinar el número!")
while True:
    intentos += 1
    try:
        numero_usuario = int(input("Adivina el número (entre 1 y 100): "))
    except ValueError:
        print("Por favor, ingresa un número válido.")
        continue
    if numero_usuario < numero_secreto:
        print("El numero es muy bajo intenta con uno mas alto")
    elif numero_usuario > numero_secreto:
        print("El numero es muy alto intenta con uno mas bajo")
    else:
        print(f"¡Felicidades! Adivinaste el número {numero_secreto} en {intentos} intentos.")
        break
# Out:
# ¡Bienvenido al juego de adivinar el número!
# Adivina el número (entre 1 y 100): 50
# El numero es muy alto intenta con uno mas bajo
# Adivina el número (entre 1 y 100): 25
# El numero es muy alto intenta con uno mas bajo
# Adivina el número (entre 1 y 100): 15
# El numero es muy alto intenta con uno mas bajo
# Adivina el número (entre 1 y 100): 5
# El numero es muy bajo intenta con uno mas alto
# Adivina el número (entre 1 y 100): 10
# El numero es muy bajo intenta con uno mas alto
# Adivina el número (entre 1 y 100): 13
# El numero es muy bajo intenta con uno mas alto
# Adivina el número (entre 1 y 100): 14
# ¡Felicidades! Adivinaste el número 14 en 7 intentos.

# %% [markdown]
# #**Crear una Calculadora basica en la consola**
#
#
#
# Intentar (try) pedir al usuario el primer número input.
#
# Corregir (except) un ValueError si no escribe un número válido.
#
# Pedir la operación (ej. "+", "-", "*", "/").
#
# Intentar (try) pedir el segundo número input.
#
# Capturar (except) un ValueError si no es válido.
#
# Usar un bloque if/elif/else para comprobar qué operación eligió.
#
# Intentar (try) realizar el cálculo.
#
# Capturar (except) un ZeroDivisionError si el usuario intentó dividir por cero.
#
# Mostrar el resultado.

# %%
print("Bienvenido a la calculadora")

while True:

    try:
        numero1 = float(input("Ingresa el primer número: "))
    except ValueError:
        print("Ingresar un numero valido")
        continue

    try:
        operacion = input("Ingresa la operacion")
    except ValueError:
        print("Ingresar una operación valida")
        continue

    try:
     numero2 = float(input("Ingresa el segundo numero: "))
    except ValueError:
        print("Ingresar un numero valido")
        continue

    try:

        if operacion == "+":
            resultado = numero1 + numero2
        elif operacion == "-":
            resultado = numero1 - numero2
        elif operacion == "*":
            resultado = numero1 * numero2
        elif operacion == "/":
            resultado = numero1 / numero2
        else:
            print("Operación no válida.")
            continue

        print(f"El resultado de {numero1} {operacion} {numero2} es: {resultado}")
        break

    except ZeroDivisionError:
        print("Error: No se puede dividir entre cero.")
# Out:
# Bienvenido a la calculadora
# Ingresa el primer número: 3.141592653589793
# Ingresa la operacion/
# Ingresa el segundo numero: 2.718281828459045
# El resultado de 3.141592653589793 / 2.718281828459045 es: 1.1557273497909217
